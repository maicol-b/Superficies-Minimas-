# %% [markdown]
# <a href="https://colab.research.google.com/github/maicol-b/Superficies-minimas-/blob/main/Superficies_conocidas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Algunas Superficies Minimas Famosas

# %% [markdown]
# # Superficie de Scherk’s

# %% [markdown]
# Para nuestra primera superficie mínima, queremos construir y analizar una superficie famosa, llamada superficie periódica simple de Scherk. Elegimos la función holomorfa f y
# función meromórfica g en el dominio $D=\left \{z\in\mathbb{C}:\left | z \right |<1  \right \}$, el círculo unitario abierto
# \begin{equation*}
#  \begin{split}
# \mu(z)=\frac{8}{1-z^4},\hspace{0.5cm}\nu(z)=i z
# \end{split}
# \end{equation*}
#
# Claramente, $\mu$ y $\nu$ son funciones  holomorfas en el dominio elegido junto con $\mu \nu^2$
# , por lo que $\nu$ también es
# meromórfico. También notamos que debido a que $\nu$ no tiene polos en D,$\mu$ no tiene ceros allí.

# %% [markdown]
# \begin{equation*}
#  \begin{split}
# X(u,v)&=\Re e\left [2\log \left ( \frac{z+1}{z-1} \right ),-2\log \left ( \frac{z+i}{z-i} \right ),2i\cdot \log\left ( \frac{z^2+1}{z^2-1} \right )\right ]\\
# &=\Re e\left [2 \ln \left | \frac{z+1}{z-1} \right |+2i\cdot \text{Arg}\left ( \frac{z+1}{z-1} \right ),- 2\ln \left | \frac{z+i}{z-i} \right |-2i\cdot \text{Arg}\left ( \frac{z+1}{z-1} \right ), 2i\cdot \ln \left | \frac{z^2-1}{z^2+1} \right |+2\text{Arg}\left ( \frac{z^2-1}{z^2+1} \right ) \right ]\\
# &=\left [ 2\ln \left | \frac{z+1}{z-1} \right |,- 2\ln \left | \frac{z+i}{z-i} \right |, 2\text{Arg}\left ( \frac{z^2-1}{z^2+1} \right ) \right ]\\
# &=\left ( 2\ln \left ( \sqrt{\frac{(x+1)^2+y^2}{(x-1)^2+y^2} }\right ),-2 \ln \left ( \sqrt{\frac{(y+1)^2+x^2}{(y-1)^2+x^2} }\right ), 2\arctan\left (  \frac{4xy}{(x^2+y^2)-1)}\right ) \right )\\
# &=\left ( \ln \left ( \frac{(x+1)^2+y^2}{(x-1)^2+y^2} \right ), \ln \left ( \frac{(y-1)^2+x^2}{(y+1)^2+x^2 }\right ), 2\arctan\left (  \frac{4xy}{(x^2+y^2)-1)}\right ) \right )
# \end{split}
# \end{equation*}
#
# Esta parametrización genera la superficie representada

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [texto del vínculo](https://www.geogebra.org/classic/pharsssd)

# %% [markdown]
# \begin{equation*}
#  \begin{split}
# \mu(z)=\frac{8}{1+z^6},\hspace{0.5cm}\nu(z)= z^2
# \end{split}
# \end{equation*}
#
# Claramente, $\mu$ y $\nu$ son funciones  holomorfas en el dominio elegido junto con $\mu \nu^2$
# , por lo que $\nu$ también es
# meromórfico. También notamos que debido a que $\nu$ no tiene polos en D,$\mu$ no tiene ceros allí.

# %% [markdown]
# \begin{equation*}
#  \begin{split}
# X(u,v)&=\Re e\left [\frac{1}{8\sqrt{3}}\log \left ( \frac{z^2+\sqrt{3}z+1}{z^2-\sqrt{3}z+1} \right ),\frac{1}{6}\log \left ( \frac{z-i}{z+i} \right )+\frac{1}{12}\log \left ( \frac{z^2-iz-1}{z^2+iz-1} \right ),\frac{1}{3}\arctan\left ( z^3 \right )\right ]\\
# &=\Re e\left [\frac{1}{8\sqrt{3}} \ln \left |  \frac{z^2+\sqrt{3}z+1}{z^2-\sqrt{3}z+1} \right |+\frac{1}{8\sqrt{3}}i\cdot \text{Arg}\left ( \frac{z^2+\sqrt{3}z+1}{z^2-\sqrt{3}z+1} \right ),\frac{1}{6}\ln \left | \frac{z+i}{z-i} \right |+\frac{1}{12}\ln \left |  \frac{z^2-iz-1}{z^2+iz-1} \right |+\frac{1}{6}i\cdot \text{Arg}\left ( \frac{z+1}{z-1} \right )++\frac{1}{12}i\cdot \text{Arg}\left (\frac{z^2-iz-1}{z^2+iz-1} \right ), \frac{1}{2i}\cdot \ln \left | \frac{iz^3+1}{1-iz^3} \right |+\frac{1}{6}\text{Arg}\left ( \frac{iz^3+1}{1-iz^3} \right ) \right ]\\
# &=\left [ \frac{1}{8\sqrt{3}} \ln \left |  \frac{z^2+\sqrt{3}z+1}{z^2-\sqrt{3}z+1} \right |,\frac{1}{6}\ln \left | \frac{z+i}{z-i} \right |+\frac{1}{12}\ln \left |  \frac{z^2-iz-1}{z^2+iz-1} \right |, \frac{1}{3}\text{Arg}\left ( \frac{iz^3+1}{1-iz^3} \right ) \right ]\\
# &=\left ( \frac{1}{8\sqrt{3}} \ln \left |  \frac{\frac{1}{\sqrt{3}}\left ( z+\frac{1}{z} \right )+1}{\frac{1}{\sqrt{3}}\left ( z+\frac{1}{z} \right )-1} \right |,\frac{1}{6}\ln \left | \frac{z+i}{z-i} \right |+\frac{1}{12} \ln \left |  \frac{\left ( z-\frac{1}{z} \right )-i}{\left ( z-\frac{1}{z} \right )+i} \right |, 2\arctan\left (  \frac{4xy}{(x^2+y^2)-1)}\right ) \right )\\
# &=
# \end{split}
# \end{equation*}

# %% [markdown]
# # Superficie de Syndler

# %% [markdown]
# La próxima superficie mínima que creamos tiene una parametrización mucho menos complicada.
# y contiene una auto-intersección. Elegimos las funciones
#
# \begin{equation*}
#  \begin{split}
# \mu(z)=1,\hspace{0.5cm}\nu(z)= e^{\sqrt{z}}
# \end{split}
# \end{equation*}
#
# Elegimos el dominio D para que sea el círculo abierto en $C$ con radio 10. En este dominio, ambas funciones son
# holomorfas por lo tanto se cumplen todas las condiciones para emplear la formula de Representación de  Weierstrass-Enneper
# , por lo que procedemos a encontrar los componentes de tal parametrización las cuales van a estar dadas por
#
# \begin{equation*}
#  \begin{split}
# X(u,v)&=\Re e\left [-\frac{1}{2}\sqrt{z}\cdot e^{2\sqrt{z}}+\frac{1}{2}z+\frac{1}{4}e^{2\sqrt{z}},\frac{i}{2}\sqrt{z}\cdot e^{2\sqrt{z}}+\frac{i}{2}z-\frac{i}{4}e^{2\sqrt{z}},2(\sqrt{z}-1)e^{\sqrt{z}}\right ]\\
# &=\Re e\left [-\frac{1}{2}\sqrt{re^{iΘ}}\cdot e^{2\sqrt{re^{iΘ}}}+\frac{1}{2}re^{iΘ}+\frac{1}{4}e^{2\sqrt{re^{iΘ}}},\frac{i}{2}\sqrt{re^{iΘ}}\cdot e^{2\sqrt{re^{iΘ}}}+\frac{i}{2}re^{iΘ}-\frac{i}{4}e^{2\sqrt{re^{iΘ}}},2(\sqrt{re^{iΘ}}-1)e^{\sqrt{re^{iΘ}}}\right ]\\
# &=\left [ \frac{r}{2}\cos(Θ)+\frac{1}{4}e^{2\cdot \sqrt{r}\cos\left ( \frac{\Theta }{2} \right )}\cdot \cos\left ( 2\cdot \sqrt{r}\sin\left ( \frac{\Theta }{2} \right ) \right )-\frac{\sqrt{r}}{2}e^{\sqrt{r}\cdot \cos\left ( \frac{\Theta }{2} \right )}\cos\left ( \frac{\Theta }{2} \right )\cdot\cos\left ( 2\cdot \sqrt{r}\sin\left ( \frac{\Theta }{2}\right ) \right )+\frac{\sqrt{r}}{2}e^{\sqrt{r}\cdot \cos\left ( \frac{\Theta }{2} \right )}\sin\left ( \frac{\Theta }{2} \right )\cdot\sin\left ( 2\cdot \sqrt{r}\sin\left ( \frac{\Theta }{2}\right ) \right ),-\frac{r}{2}\sin(\Theta )+\frac{1}{4}e^{2\cdot \sqrt{r}\cos\left ( \frac{\Theta }{2} \right )}\cdot \sin\left ( 2\cdot \sqrt{r}\sin\left ( \frac{\Theta }{2} \right ) \right )-\frac{\sqrt{r}}{2}e^{2\sqrt{r}\cdot \cos\left ( \frac{\Theta }{2} \right )}\sin\left ( \frac{\Theta }{2} \right )\cdot\cos\left ( 2\cdot \sqrt{r}\sin\left ( \frac{\Theta }{2}\right ) \right )-\frac{\sqrt{r}}{2}e^{\sqrt{r}\cdot \cos\left ( \frac{\Theta }{2} \right )}\cos\left ( \frac{\Theta }{2} \right )\cdot\sin\left ( 2\cdot \sqrt{r}\sin\left ( \frac{\Theta }{2}\right ) \right ),2\cdot \sqrt{r}e^{\sqrt{r}\cdot \cos\left ( \frac{\Theta }{2} \right )}\cdot \cos\left ( \sqrt{r}\cdot \sin\left ( \frac{\Theta }{2} \right ) \right )\cdot \cos\left ( \frac{\Theta }{2} \right )-2\cdot e^{\sqrt{r}\cos\left ( \frac{\Theta }{2} \right )}\cos\left ( \sqrt{r}\sin\left ( \frac{\Theta }{2} \right ) \right )-2\sqrt{r}e^{\sqrt{r}\cos\left ( \frac{\Theta }{2} \right )}\sin\left ( \sqrt{r}\cdot \sin\left ( \frac{\Theta }{2} \right ) \right )\cdot \sin\left ( \frac{\Theta }{2} \right )    \right ]
# \end{split}
# \end{equation*}

# %% [markdown]
# Para $r \in (0, 10)$ y $Θ ∈ (−\pi, \pi)$. A esta superficie mínima la llamamos superficie de Snyder
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [texto del vínculo](https://www.geogebra.org/classic/g2q7xyqz)

# %% [markdown]
# La segunda superficie mínima que construimos es la nuestra. Elegimos el dominio $D=\left \{z\in \mathbb{C}:\left | z \right |<1  \right \}$ con la restricción de que $−π < θ < π$. Esto es para asegurarse de que
# nuestras funciones son univaluadas y continuas en D. Elegimos la función compleja
#
# \begin{equation*}
#  \begin{split}
# \mu(z)=1,\hspace{0.5cm}\nu(z)=\arccos(z)
# \end{split}
# \end{equation*}
#
# Las funciones $\mu$ y $\nu$ son holomorfas en D, por lo que claramente $\mu\nu^2$
# es holomorfa, y ν
# es meromórfa. No hay polos de ν, y por lo tanto no hay ceros de f. Volvemos a calcular las componentes de una parametrización $X(r, θ)$ con el contorno $γ ⊂ D$
#
#
# \begin{equation*}
#  \begin{split}
# X(u,v)&=\Re e\left [ -\frac{1}{2}z \arccos^2{z}+\frac{3}{2}z+\sqrt{1-z^2}\arccos(z),\frac{i}{2}z \arccos^2{z}-\frac{i}{2}z-i\sqrt{1-z^2}\arccos(z), z\arccos(z)-\sqrt{1-z^2}\right ]\\
# &=
# \end{split}
# \end{equation*}

# %% [markdown]
# #Catenoide

# %% [markdown]
# Elegimos el dominio $D=\left \{z\in \mathbb{C}:0<\left | z \right |<1  \right \}$ con la restricción de que $−π < θ < π$. Esto es para asegurarse de que
# nuestras funciones son univaluadas y continuas en D. Elegimos las funciónes complejas
#
# \begin{equation*}
#  \begin{split}
# \mu(z)=1,\hspace{0.5cm}\nu(z)=\frac{1}{z}
# \end{split}
# \end{equation*}
#
#
# Las funciones $\mu$ y $\nu$ son holomorfas en D, por lo que claramente $\mu\nu^2$
# es holomorfa, y ν
# es meromórfa. No hay polos de $\nu$, y por lo tanto no hay ceros de f. Volvemos a calcular las componentes de una parametrización $X(u, v)$ con el contorno $γ ⊂ D$
#
# \begin{equation*}
#  \begin{split}
# X(u,v)&=\Re e\left [ \frac{1}{2} z+\frac{1}{2 z},\frac{i}{2} z-\frac{i}{2z},\log(z)\right ]\\
# &=\Re e\left [ \frac{1}{2} r e^{i\theta}+\frac{1}{2r} e^{-i\theta},\frac{i}{2} r e^{i\theta}-\frac{i}{2r}e^{-i\theta},\log(r e^{i\theta})\right ]\\
# &=\left [ \frac{1}{2}\left ( r +\frac{1}{r} \right )\cos(\theta ), \frac{1}{2}\left ( r +\frac{1}{r} \right )\cdot \sin(\theta ),\log(r) \right ]
# \end{split}
# \end{equation*}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [texto del vínculo](https://www.geogebra.org/m/xvfatyhm)

# %% [markdown]
# # Helicoide

# %% [markdown]
# Elegimos el dominio $D=\left \{z\in \mathbb{C}:0<\left | z \right |<1  \right \}$ con la restricción de que $−π < θ < π$. Esto es para asegurarse de que
# nuestras funciones son univaluadas y continuas en D. Elegimos las funciónes complejas
#
# \begin{equation*}
#  \begin{split}
# \mu(z)=i,\hspace{0.5cm}\nu(z)=\frac{1}{z}
# \end{split}
# \end{equation*}
#
#
# Las funciones $\mu$ y $\nu$ son holomorfas en D, por lo que claramente $\mu\nu^2$
# es holomorfa, y ν
# es meromórfa. No hay polos de $\nu$, y por lo tanto no hay ceros de f. Volvemos a calcular las componentes de una parametrización $X(u, v)$ con el contorno $γ ⊂ D$
#
# \begin{equation*}
#  \begin{split}
# X(u,v)&=\Re e\left [\frac{i}{2} z+\frac{i}{2z},\frac{1}{2} z-\frac{1}{2 z},i\log(z)\right ]\\
# &=\Re e\left [ \frac{i}{2} r e^{i\theta}+\frac{i}{2r} e^{-i\theta},\frac{1}{2} r e^{i\theta}-\frac{1}{2r}e^{-i\theta},i\log(r e^{i\theta})\right ]\\
# &=\left [ \frac{1}{2}\left ( \frac{1}{r} - r\right )\sin(\theta ), \frac{1}{2}\left (r-\frac{1}{r}  \right )\cdot \cos(\theta ),\theta \right ]
# \end{split}
# \end{equation*}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [texto del vínculo](https://www.geogebra.org/m/t3q5cc6z)

# %% [markdown]
# #Superficie de Jeener's flower

# %% [markdown]
# Ahora elegimos el dominio $D=\left \{z\in \mathbb{C}  \right \}$ con la restricción de que $−π < θ < π$ y elegimos las funciónes complejas
#
# \begin{equation*}
#  \begin{split}
# \mu(z)=z^2,\hspace{0.5cm}\nu(z)=z
# \end{split}
# \end{equation*}
#
#
# Las funciones $\mu$ y $\nu$ son holomorfas en D, por lo que claramente $\mu\nu^2$
# es holomorfa, y ν
# es meromórfa. No hay polos de $\nu$, y por lo tanto no hay ceros de f. Volvemos a calcular las componentes de una parametrización $X(u, v)$ con el contorno $γ ⊂ D$
#
# \begin{equation*}
#  \begin{split}
# X(u,v)&=\Re e\left [\frac{z^3}{6}-\frac{1}{10}z^5,\frac{iz^5}{10}+\frac{iz^3}{6},\frac{z^4}{4}\right ]\\
# &=\Re e\left [\frac{r^3 e^{3i\theta}}{6}-\frac{1}{10}r^5 e^{5i\theta},\frac{ir^5 e^{5i\theta}}{10}+\frac{ir^3 e^{3i\theta}}{6},\frac{r^4 e^{4i\theta}}{4}\right ]\\
# &=\left [ \frac{r^3 }{6}\cos(3θ)-\frac{1}{10}r^5\cos(5θ),-\frac{r^5 }{10}\sin(5θ)-\frac{r^3 }{6}\sin(3θ),\frac{r^4 }{4}\cos(4θ)\right ]
# \end{split}
# \end{equation*}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [texto del vínculo](https://www.geogebra.org/classic/h4qztjyt)

# %% [markdown]
# # Superficie minima de Meeks

# %% [markdown]
# \begin{equation*}
#  \begin{split}
# \mu(z)=\frac{i(z+1)^2}{z^4},\hspace{0.5cm}\nu(z)=\frac{(z-1)z^2}{z+1}
# \end{split}
# \end{equation*}
#
# \begin{equation*}
#  \begin{split}
# X(u,v)&=\Re e\left [-\frac{i}{6}z^3 +\frac{i}{2}z^2-\frac{i}{6}z-\frac{i}{2z}-\frac{i}{2z^2}-\frac{i}{6z^3}, -\frac{1}{6}z^3 +\frac{1}{2}z^2-\frac{1}{6}z+\frac{1}{2z}+\frac{1}{2z^2}+\frac{1}{6z^3},iz+\frac{i}{z}     \right ]\\
# &=\left [-\frac{i}{6}r^3e^{3i\theta} +\frac{i}{2}r^2e^{2i\theta}-\frac{i}{6}re^{i\theta}-\frac{i}{2r}e^{-i\theta}-\frac{i}{2r^2}e^{-2i\theta}-\frac{i}{6r^3}e^{-3i\theta}, -\frac{1}{6}r^3e^{3i\theta} +\frac{1}{2}r^2e^{2i\theta}-\frac{1}{6}re^{i\theta}+\frac{1}{2r}e^{-i\theta}+\frac{1}{2r^2}e^{-2i\theta}+\frac{1}{6r^3}e^{-3i\theta},ire^{i\theta}+\frac{i}{r}e^{-i\theta}\right ]\\
# &=\left [ \frac{1}{6}r^3 \sin(3\theta )-\frac{1}{2}r^2 \sin(2\theta )+\frac{1}{6}r\sin(\theta )-\frac{1}{2r}\sin(\theta )-\frac{1}{2r^2}\sin(2\theta )-\frac{1}{6r^3}\sin(3\theta ),-\frac{1}{6}r^3 \cos(3\theta )+\frac{1}{2}r^2 \cos(2\theta )-\frac{1}{6}r\cos(\theta )+\frac{1}{2r}\cos(\theta )+\frac{1}{2r^2}\cos(2\theta )+\frac{1}{6r^3}\cos(3\theta ),\left ( \frac{1}{r} -r\right )\sin(\theta )  \right ]
# \end{split}
# \end{equation*}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [texto del vínculo](https://www.geogebra.org/classic/n7sbtyh9)

# %% [markdown]
# # Trinoides y los n-noides

# %% [markdown]
# Tomemos las funciónes complejas
#
# \begin{equation*}
#  \begin{split}
# \mu(z)=\frac{1}{(z^n-1)^2},\hspace{0.5cm}\nu(z)=z^{n-1}
# \end{split}
# \end{equation*}
#
# Caso en donde   $n= 2$
# \begin{equation*}
#  \begin{split}
# X(u,v)&=\Re e \left [ \frac{1}{4}\log\left ( \frac{z+1}{z-1} \right ),-\frac{i}{2} \left ( \frac{z}{z^2-1} \right ),-\frac{1}{2} \left ( \frac{1}{z^2-1} \right )\right ]\\
# &=\Re e\left [ \log\left |\frac{z+1}{z-1}\right |+i\text{Arg}\left ( \frac{z+1}{z-1} \right ),-\frac{i}{4(z-1)}-\frac{i}{4(z+1)},-\frac{1}{4(z-1)}+\frac{1}{4(z+1)}\right ]\\
# &=\left [ \log\left (\sqrt{\frac{(x+1)^2+y^2}{(x-1)^2+y^2}}\right ),-\frac{1}{4}\left (\frac{y}{(x-1)^2+y^2}+\frac{y}{(x+1)^2+y^2}  \right ),\frac{1}{4}\left ( \frac{x+1}{(x+1)^2+y^2}-\frac{x-1}{(x-1)^2+y^2}\right )\right ]
# \end{split}
# \end{equation*}

# %% [markdown]
# [texto del vínculo](https://www.geogebra.org/classic/pvngxuj3)
